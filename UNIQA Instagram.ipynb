# %% [markdown]
# ## UNIQA Instagram

# %% [markdown]
# Instagram shut down its public API in 2018. You now have to be approved through Facebook before hand, and many of the functionality only works if your account has been verified as a business account. Similarly to how I handled Twitter, I will be attempting to use Apify to scrape Instagram. They have an `Instagram Scraper` and an `Instagram Profile Scraper`. *Otherwise, I could go on Instagram and manually grab the posts, comments, and threads myself possibly.*

# %%
#importing libraries
import pandas as pd

# %%
#This was queried based on UNIQA's instagram URL (@uniqa.at)
instagram_uniqa = pd.read_csv('dataset_instagram_scraper.csv')
instagram_uniqa
# Out:
#                                                    alt  \
# 0    Photo by UNIQA on April 03, 2024. May be an im...
# 1    Photo by UNIQA on April 10, 2024. May be an im...
# 2    Photo by UNIQA on April 11, 2024. May be an im...
# 3                                                  NaN
# 4    Photo by UNIQA on March 29, 2024. May be an im...
# ..                                                 ...
# 477                                                NaN
# 478               Photo by UNIQA on February 02, 2018.
# 479               Photo by UNIQA on February 13, 2018.
# 480               Photo by UNIQA on February 01, 2018.
# 481               Photo by UNIQA on February 09, 2018.
#
#                                                caption  \
# 0    #Anzeige \n\n☀️ Letzten Sommer waren die Öster...
# 1    Anzeige | Mit dem UNIQA VitalPlan kannst du de...
# 2    Ohren auf… 👀\nIn der neuen Folge unseren Podca...
# 3    Die Übung "Die Uhr" kannst du in wenigen Sekun...
# ...

# %%
filtered_comments = [comment for comment in instagram_uniqa['firstComment'] if pd.notnull(comment)]
filtered_comments
# Out:
# ['Nachts 3 Stunden auf TikTok scrollen wahrscheinlich nicht... 👀',
#  'Same here 🙌 Krafttraining hat Frauenpower verdient 💯',
#  '🙌🔥',
#  'Und Trash-Tv einschalten. ☝️😌',
#  'Glaube nicht, dass es egoistisch ist. 🤔',
#  'Kohl!!! Wir leben in Österreich, da gibt es keinen Wirsing!!!',
#  'Unser liebster Hack - Oma-Spruc:" Nach dem Essen sollst du ruhen oder 1000 Schritte tun! "❤️',
#  'Wenn interessiert, was Ihr Raubritter postet. 12,75% Prämienerhöhung bei meiner KV. Und bei den Leistungen blockt ihr ab. Schämt Euch. Kein Wunder, dass niemand privat mit Versicherungstypen zu tun haben will.',
#  '🤍🤍🤍',
# ...

# %%
len(filtered_comments)
#269 comments on 482 UNIQA posts
# Out:
# 269

# %% [markdown]
# So far this has worked surprisingly well actually, and I was able to get all of this data for free. The `Instagram Scraper` on Apify allows up to 5 dollars of free usage and this cost me about $0.60.

# %% [markdown]
# ## #UNIQA
# Querying based on #UNIQA rather than the Instagram URL

# %%
instagram_uniqa_hashtag = pd.read_csv('uniqa_ig_hashtag.csv')
instagram_uniqa_hashtag
# Out:
#                   id                                       inputUrl  \
# 0  17844010048051530  https://www.instagram.com/explore/tags/uniqa/
#
#                                    latestPosts/0/alt  \
# 0  Photo by UNIQA Macedonia on April 18, 2024. Ma...
#
#                                latestPosts/0/caption  \
# 0  Сега можете брзо и лесно да ја платите Вашата ...
#
#    latestPosts/0/commentsCount  latestPosts/0/dimensionsHeight  \
# 0                            0                            1080
#
#    latestPosts/0/dimensionsWidth  \
# 0                           1080
#
#                             latestPosts/0/displayUrl  \
# 0  https://instagram.fpiu2-2.fna.fbcdn.net/v/t51....
#
#    latestPosts/0/firstComment latestPosts/0/hashtags/0  ...  \
# 0                         NaN                    UNIQA  ...
#
#   topPosts/8/likesCount topPosts/8/mentions/0 topPosts/8/mentions/1  \
# 0                  2438         kleinezeitung      christianecanori
#
# ...

# %%
#how many posts with #UNIQA
instagram_uniqa_hashtag.postsCount
#41,545 posts that use the #UNIQA, although most likely many of these
#are not related to UNIQA Insurance
# Out:
# 0    41545
# Name: postsCount, dtype: int64

# %% [markdown]
# ## SEE what data analysis I can do with this

# %%
insurance_caption = [caption for caption in instagram_uniqa.caption if isinstance(caption, str) and ('versicherung' in caption.lower() or 'insurance' in caption.lower())]
insurance_caption
# Out:
# ['#Anzeige \n\n☀️ Letzten Sommer waren die Österreicher:innen wieder voll im Reisefieber. Über 22 Prozent aller Trips ins Ausland gingen nach Bella Italia – damit war Italien unser Urlaubsziel Nummer 1. \n\nHast du schon Urlaubspläne für dieses Jahr? \u200b\n\nGanz gleich, ob es nach Italien geht oder ans andere Ende der Welt, mit der UNIQA Reiseversicherung Rundumschutz bist du immer sorgenfrei unterwegs. Jetzt einfach online abschließen!\u200b\n\nLink in Bio.\u200b\n\n#GemeinsamBesserLeben #UNIQA #Reisen #Reiseversicherung #Travel',
# ...

# %%
len(insurance_caption)
#There seem to be 44 captions (and therefore posts of the 482 related to UNIQA insurance)! *could be a sign
#that UNIQA needs to engage more with customers- giveaways, asking customers to post related to UNIQA??
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(insurance_caption)
#
# NameError: name 'insurance_caption' is not defined

# %%
insurance_caption[0]
# Out:
# '#Anzeige \n\n☀️ Letzten Sommer waren die Österreicher:innen wieder voll im Reisefieber. Über 22 Prozent aller Trips ins Ausland gingen nach Bella Italia – damit war Italien unser Urlaubsziel Nummer 1. \n\nHast du schon Urlaubspläne für dieses Jahr? \u200b\n\nGanz gleich, ob es nach Italien geht oder ans andere Ende der Welt, mit der UNIQA Reiseversicherung Rundumschutz bist du immer sorgenfrei unterwegs. Jetzt einfach online abschließen!\u200b\n\nLink in Bio.\u200b\n\n#GemeinsamBesserLeben #UNIQA #Reisen #Reiseversicherung #Travel'

# %% [markdown]
# ## Translations of the 44 captions
#
# "#Advertisement ☀️ Last summer, Austrians were once again in full travel mode. Over 22 percent of all trips abroad went to Bella Italia - making Italy our number 1 holiday destination. \n\nDo you already have vacation plans for this year? \u200b\n\nWhether it's Italy or the other end of the world, with UNIQA Travel Insurance, you can always travel worry-free. Simply sign up online now!\u200b\n\nLink in Bio.\u200b\n\n#TogetherBetterLiving #UNIQA #Travel #TravelInsurance"
# "Advertisement | With the UNIQA VitalPlan, you can take your private health insurance to a new level: \n\n✔️ Receive personal advice from VitalCoaches on nutrition, exercise, or mental fitness. \n✔️ Regular, comprehensive preventive check-ups help you identify and treat health risks faster. \n✔️ Or take a scientifically based genetic test to find out how you can optimize your diet and exercise based on your genes. \n\n#WorldHealthDay #TogetherBetterLiving"
# "Well-planned is half won - that also applies to vacation planning. We have put together some tips to help you save your travel budget.\u200b\n\n✈️ With Blind Booking, you can book flights and hotels at a low price, while only finding out where the trip is going after booking. \u200b\n\n🎟️ Buy your tickets for tourist attractions online. Often, you can get your ticket for up to 50% off this way.\u200b\n\n🧳 Choose the right travel insurance. This is important to cover unforeseen expenses during your vacation.\u200b\n\nFind even more tips on how to make your vacation more affordable in the article. Link in Bio.\n\n#TogetherBetterLiving #UNIQA #Vacation #Travel #Save #Holiday #Travel"
# "Traveling and environmental awareness - a dilemma for many who want to see the world. The good news: Sustainable travel is possible. Good preparation starts even before departure.\u200b\n\n🔌 Start saving electricity: Turn off lights at home, close windows properly, and unplug all plugs from the sockets.\u200b\n\n🧳 Packing less means less weight - which means less kerosene or gasoline consumption in airplanes or cars.\u200b\n\n💚 Choose environmentally friendly accommodations such as hotels with environmental certification or prefer self-sufficient "Ecolodges."\u200b\n\nFind even more tips in the article. Link in Bio.\n\n#TogetherBetterLiving #UNIQA #Travel #TravelInsurance"
# "Scary moment in the World Cup downhill in Bormio: Medal hopeful Marco Schwarz crashes hard, ending the World Cup season for him. But Marco doesn't let it get him down: After his surgery, he starts his rehabilitation with full determination. \n\nThe new ORF documentary "ComeBLACK - in the Shadow of Triumph" accompanies him on his way back after his serious fall. The first part can be seen on Friday, March 1, 2024, at 8:15 p.m. on ORF 1. \n\nOur partnership with Marco Schwarz remains unchanged, as board member Kurt Svoboda reaffirms: "Unexpected events happen - and that's exactly what insurance is for. In addition to this protection, it takes perseverance, discipline, and personal motivation. Marco Schwarz is the epitome of this. We see this in this impressive documentary and surely also in the upcoming World Cup season and at the Home World Championship, where Marco will attack again with the blue UNIQA helmet." \n\n📷 Ski Austria/ORF\n\n#TogetherBetterLiving #ComeBackStronger #SkiAustria"
# "Minor accidents, big worries? It doesn't have to be that way. Especially when it comes to our little ones, quick action is crucial in case of dental accidents. \u200b\n\n🧴 Only touch teeth at the crown, do not clean or disinfect.\u200b\n🦷 Loose teeth should be removed quickly and stored in a tooth rescue box to extend their survival time.\u200b\n🥣 After dental injuries, only eat soft food for a week, avoid sugary foods.\u200b\n\nFind even more tips in the article. Link in Bio.\n\n#TogetherBetterLiving #UNIQA #DentalInsurance"
# "How much is your pension (ideally☝️)?\nFor your pension amount, the so-called 45-65-80 rule applies. This means that if you retire at the regular retirement age (at 65 👵 👴), after 45 years of insurance, you will receive 80% of your total average monthly income.\nPart-time employment or non-employment unfortunately negatively affect this amount. 🥲\nTherefore, early provision is all the more important.\n\nFind out more about provision via the link in our bio.\n\n#TogetherBetterLiving #UNIQA #Finance #Pension #Money #Future #Invest \nMore information about insurance can be found on www.uniqa.at in the basic information sheet. Advertisement."
# "What is the pension gap? How does it arise? And why does it affect women more? 😵\u200d💫\nUNIQA advisor Carina explains.\n\n#TogetherBetterLiving #UNIQA #Finance #Pension #Money #Future #Invest #PensionGap \nMore information about insurance can be found on www.uniqa.at in the basic information sheet. Advertisement."
# "Saving account, stocks, bonds... Have you ever thought about investment options and which one is right for your financial provision? 🤔\n\nFind out more about provision via the link in our bio.\n\n#TogetherBetterLiving #UNIQA #Finance #Pension #Money #Future #Invest \nMore information about insurance can be found on www.uniqa.at in the basic information sheet. Advertisement."
# "Financial provision is expensive (?). 🫣\nUNIQA advisor Carina has calculated this for you once. 🤓 \n\nYou invest 100€ per month in a classic life insurance policy at the age of 25. ➡️ Then you will receive about 150€ per month in addition to your pension*.\n \nFind out more about provision via the link in our bio.\n\n#TogetherBetterLiving #UNIQA #Finance #Pension #Money #Future #Invest \nMore information about insurance can be found on www.uniqa.at in the basic information sheet. Advertisement.\n\n*Assumption: Premium payment until 65, assumed total interest rate 2% p.a., non-binding example with rounded values.�We cannot predict profits that can be achieved in future years. Therefore, the figures given for profit sharing are based on estimates. These are based on the current conditions, so such information is non-binding. Past allocations do not allow any conclusions to be drawn about future results."
# "Don't want to worry about money even in old age? 🤑\n\nWe'll tell you how much more you'll have per month if you start saving early. In our example, we assume that you invest 100 euros per month in a unit-linked life insurance policy, with the premium increasing by 2% each year.\n\n*Term until your 65th birthday, annual dynamism parameter 2%, assumed performance 4% p.a.\n\n#UNIQA #TogetherBetterLiving #Finance #Provision #Finances #Knowledge #FinancialKnowledge"
# "Most accidents happen where the insurance coverage of statutory accident insurance is not sufficient: in leisure time. Did you know that only about half of all Austrians have private accident insurance? Yet it offers many advantages:\n\n🌍 You are protected worldwide and 24/7.\n🧒 From toddlers to old age.\n🚘 Even self-inflicted accidents are covered.\n\nFind out more via the link in the bio.\n\n#TogetherBetterLiving #SafetyFirst #UNIQA"
# "Our everyday life can change in seconds. Accidents and their consequences bring not only physical but also financial burden. 😩\nBut only a portion of all accidents and their financial consequences are covered by statutory accident insurance. It is important to distinguish: Does the accident happen at work 👷 or during leisure time ⚽? \n\nFind out what statutory accident insurance pays for in the article. Link in Bio.\n\n#TogetherBetterLiving #UNIQA #SafetyFirst"
# "⛱️ Finally vacation, time to relax. When packing your suitcase, we often neglect the safety of our own home. What you should think about to protect your home optimally and to receive your entitlement in case of damage. \n\n🚪 Better check twice if all windows and doors are closed before leaving the house.\n🔑 Don't hide spare keys. If burglars find your keys, you won't have insurance coverage.\n💧Away for more than 72 hours? Then, if possible, turn off the main water tap. \n\nFind more tips in the article. Link in Bio.\n\n#Holiday #Vacation #HomeInsurance #TogetherBetterLiving"
# "Iron, stove, or coffee maker: When electrical appliances accidentally remain switched on, a fire can occur 🧯. Whether a damage was caused lightly or grossly negligent is often unclear. Therefore, in UNIQA Household and Home Insurance, gross negligence is always included with up to 100% of the maximum maximum compensation amount. 😌\n\n#TogetherBetterLiving #UNIQA #HomeSweetHome #BetterSafeThanSorry #SafetyFirst"
# "🦷 Healthy teeth make for a radiant smile - Laughing is known to strengthen the immune system and reduce stress. \n\nTo keep the stress level low, there is the small dental insurance. Here you have free choice of doctor, get appointments quickly, and e.g. financial support for dental prostheses and jaw alignment. \nSave 8 monthly premiums now when you sign up.\n\nMore about this via the link in our bio."
# "E-bikes are becoming increasingly popular. \nIn 2021, 45% of all bicycles sold in Austria were e-bikes.\nSo that you are also covered with your bike, there is comprehensive insurance for your e-bike. This protects your e-bike even in accidents, regardless of whether it is your fault or not. \n\nLink in Bio.\n\n#TogetherBetterLiving #UNIQA #EMobility #eBike #Insurance"
# "We'll tell you what you should pay attention to when insuring your electric car. Because with an electric vehicle, you can not only protect the climate but also your wallet. \n\nLink in Bio."
# "📦🏠 After the apartment search is before the move. And for that, good planning and sufficient lead time are essential. Have you thought of everything? \n\nWith our moving checklist, you can plan your change of residence without breaking a sweat:\n▪️ Organize boxes and padding material\n▪️ Organize parking/short-term no-parking zones for the moving truck\n▪️ Cancel standing orders for the old apartment\n▪️ Change home insurance\n▪️ Change internet, television & subscriptions\n\nFind even more tips, as well as a schedule, via the link in our bio. \n\n#UNIQA #TogetherBetterReading #Moving #Checklist #MovingDay #MovingChaos #MovingStress"
# "When taking out children's insurance, the rule is: The earlier insured, the more the child benefits throughout its life. With the UNIQA FirstCare Health Insurance, the benefits adapt flexibly to the child's age and needs.\n\nLink in Bio."
# "🚲+🦝=💔\nYou and your bike, you go everywhere together?\nEven worse when it gets stolen - luckily there is bike insurance.\n\nAll information via the link in our bio.\n\nPhoto: UNIQA | Melina Kutelas"
# "The first own apartment🏡, a new job\u200d👨\u200d🚀? Sounds stressful😅?\nSo that you can relax and not worry about everything, we have put together the most important insurances for you.\n\nPhoto: UNIQA | Melina Kutelas"
# "Valid passport ✔️, check vaccination record ✔️, travel insurance ✔️.\nThe holiday season is approaching, and the first travel preparations are starting - but what else needs to be organized and packed? With our travel checklist, you can go on vacation stress-free. 🧳\n\nLink in Bio!\n\nPhoto: UNIQA | Melina Kutelas"
# "300 euros pension per month*: That's what your baby gets if you invest 25 euros per month in private pension provision from its birth. Pays off, right? The most important information about pension provision: Link in Bio. #togetherbettersupply #togetherbetterliving\n\n* 3% performance assumption. With unit-linked life insurance, the investment is made in funds of your choice from our range of funds. You bear the investment risk and can lose part or all of the invested capital."
# "What can women do to still enjoy financial freedom in retirement? Find out more via the link in our bio! \n#genderpensiongap #women #insurance #influencer #provision"
# "Women in Austria receive on average 34% less pension than men. In recent months, @klarafuchscom, @kerstinloves, @jay.rox, @iamchristlclear, @trendmum, and @lisbia_ have addressed the reasons for this gender pension gap on their channels and discussed with their community the options for provision. \nFind out more via the link in our bio on the topic of women & pension. Think self-insured, woman! #genderpensiongap #women #insurance #influencer #provision"
# "Are you thinking about the future? Especially women often have disadvantages when it comes to pension in Austria. What are the reasons for this and what you can do about it, you will find out via the link in our bio. #genderpensiongap #women #pension #insurance #influencer #provision"
# ""Bringing everything under one roof and making it look good is my job. I coordinate the advertising presence of a distribution brand." - Jutta Ofner-Krewenka, Expert Raiffeisen Insurance-Product\n#IamUNIQA\n————————————————————\nLink to the video can be found in our bio."
# "#UNIQAArtFact #UNIQAInsurance\nPhoto: Sabine Klimpt"
# "On October 17, 1891, Emperor Franz Joseph opened the @kunsthistorischesmuseumvienna. In 2016, it celebrated its 125th anniversary with a special exhibition on the subject of festival cultures.\n#UNIQAArtFact #UNIQAInsurance\nPhoto: Sabine Klimpt"
# "A composition of poetry and drama characterizes the works of #AlbrechtAltdorfer , #AlbrechtDürer , #LucasCranach, and others in which man merges with nature.\n#UNIQAArtFact #UNIQAInsurance\nPhoto: Sabine Klimpt"
# ""Fantastic Worlds" is the title of a unique exhibition on the work of #AlbrechtAltdorfer and the expressive in art around 1500. \n#UNIQAArtFact #UNIQAInsurance\nPhoto: Sabine Klimpt"
# "The exhibition includes around 80 artists, including #Klimt , #Kokoschka , and #Schiele. #BeyondKlimt #UNIQAArtFact #UNIQAInsurance Photo: Roland Rudolph"
# "#UNIQAArtFact #UNIQAInsurance\nPhoto: Sabine Klimpt"
# "In the interwar period, there was lively artistic exchange, from which constructive, expressionist, and fantastic tendencies emerged, characterized by the desire for change. #BeyondKlimt #UNIQAArtFact #UNIQAInsurance Photo: Roland Rudolph"
# ""Klimt is not the end - departure in Central Europe" is an exhibition by @belvederemuseum and @bozarbrussels in cooperation with @szepmuveszeti . #BeyondKlimt #UNIQAArtFact #UNIQAInsurance Photo: Roland Rudolph"
# "Highlights of the Picture Gallery today include the world's unique collection of paintings by #PieterBruegel the Elder and masterpieces by #Vermeer , #Rembrandt , #Raffael , #Caravaggio , #Velázquez , and Italian Baroque painting. #UNIQAArtFact #UNIQAInsurance Photo: KHM-Museumsverband"
# "Baroqueizing decorative elements condense into one of the most festive and precious interiors of Viennese late Historicism. #UNIQAArtFact #UNIQAInsurance Photo: Sabine Klimpt"
# "The walk over the stairs leads, past #AntonioCanova's Theseus group, into the dome hall, the climax of imperial self-presentation. #UNIQAArtFact #UNIQAInsurance Photo: Sabine Klimpt"
# "The Picture Gallery of the Kunsthistorisches Museum emerged from the art collections of the House of Habsburg and is one of the largest and most important in the world. #UNIQAArtFact #UNIQAInsurance Photo: Sabine Klimpt"
# "The internal structure of the @kunsthistorischesmuseumvienna combines several building traditions: vestibule, staircase, and dome hall form a dramaturgical unity celebrating the imperial builder and his predecessors. #UNIQAArtFact #UNIQAInsurance Photo: Sabine Klimpt"
# "Benvenuto Cellini's Saliera is a table vessel and an allegorical representation of the planet Earth. #UNIQAArtFact #UNIQAInsurance Photo: Sabine Klimpt"
# "#UNIQAArtFact #UNIQAInsurance\nPhoto: Sabine Klimpt"
